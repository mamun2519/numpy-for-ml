# %%
# You must run this code and use this dataset for all questions

import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# Q1
# Use  NumPy arrays ,  the emp_ages and emp_income.
#  Print both arrays and display:
# - data type
# - number of dimensions
# - shape
# - total number of elements

# %%
np_array_emp_ages = np.array(emp_ages)
np_array_emp_income = np.array(emp_income)

# age
print(np_array_emp_ages)
print(np_array_emp_ages.dtype)
print(np_array_emp_ages.ndim)
print(np_array_emp_ages.shape)
print(np_array_emp_ages.size)
# incame
print(np_array_emp_income)
print(np_array_emp_income.dtype)
print(np_array_emp_income.ndim)
print(np_array_emp_income.shape)
print(np_array_emp_income.size)
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# int64
# 1
# (50,)
# 50
# [51725 38495 35452 82295 72187 58915 76159 92864 76155 90494 68641 48079
#  56879 83682 94722 91041 48899 68744 63187 74146 75641 47678 76760 78354
#  60584 79898 59682 71888 51086 73700 82550 71447 76100 72269 73314 87428
#  94427 84188 52013 63326 44396 59500 55523 58602 90794 41061 82331 73048
#  59727 50398]
# int64
# 1
# (50,)
# 50

# %% [markdown]
# Q2.
# Using NumPy functions:
# - Find the maximum and minimum salary
# - Calculate the average salary
# - Calculate the average age
#  Print all results.

# %%
# min
min_sellery = np.min(emp_income)
print(min_sellery)
# max
max_sellery = np.max(emp_income)
print(max_sellery)
# avg
avg_sellery = np.average(emp_income)
print(avg_sellery)

# avg age
avg_age = np.average(emp_ages)
print(avg_age)
# Out:
# 35452
# 94722
# 68409.48
# 35.44

# %% [markdown]
# Q3.
# From the emp_ages array:
# Extract employees who:
# - are aged between 25 and 40,
#  AND
# Emp_salary : have salary greater than 50,000
# Then :
# - Print the filtered values
# - Count how many employees satisfy this condition

# %%
condidaiton = (emp_ages < 40) & (emp_ages > 25) & (emp_income > 50000)

# filter age and sellery
filter_age = emp_ages[condidaiton]
filter_selery = emp_income[condidaiton]

print(filter_age)
print(filter_selery)

# count
sum = np.sum(condidaiton)
print(sum)
# Out:
# [37 37 35 38 31 29 38 27 32 26 37 26 30 30 27 31]
# [72187 58915 92864 90494 68641 56879 83682 94722 74146 78354 79898 59682
#  73700 84188 52013 59727]
# 16

# %% [markdown]
# Q4.
# Create a new NumPy array where each employee’s age is adjusted based on:
# - Add 4 years if age is less than the average age
# - Add 2 years if age is greater than or equal to the average age
# Do NOT modify the original array.
#
# Print:
# - original array
# - updated array
# - average age used for condition

# %%
copy_emp_ages = emp_ages.copy()



result = np.where(copy_emp_ages >=  avg_age ,  copy_emp_ages + 2 , copy_emp_ages +4)

# copy arry print
print(result)
# print old array
print(emp_ages)
# print avg in new array
print(np.average(result))
# average used for condition
print(avg_age)

# %% [markdown]
# Q5.
# Using NumPy:
# Assume all salaries of Tech roles increase by 8%
# Calculate the new total salary expense
# Find the overall increase in expense after the raise
#
#  Print both old and new totals along with the difference.

# %%
# load sellery and roles
salary = data["emp_salary"].values
roles = data["role"].values

#print(salary)
#print(roles)
# Tech roles mask
tech_mask = (roles == "Software Developer") | (roles == "Backend Developer")

#print(tech_mask)
# old selery expence
old_total_sellery_expence = np.sum(salary)

# new sellery
new_sellery = salary.copy()
# Apply 8% increase
new_sellery[tech_mask] = new_sellery[tech_mask] * 1.08

# total new selery
new_total = np.sum(new_sellery)
print(new_total)

# incase
increase = new_total - old_total_sellery_expence

print("Old Total",old_total_sellery_expence)
print("New total",new_total)
print("increase", increase)

# %% [markdown]
# 2) Pandas — 5 Questions

# %% [markdown]
# Q6.
# Load the staff_data.csv file into a Pandas DataFrame.
# Display the first 3 rows
# Show dataset information using .info()
# Display summary statistics using .describe()

# %%
csv_file_data = pd.read_csv("staff_data.csv")
# print(csv_file_data)
print(csv_file_data.head(3))
print(csv_file_data.info())
print(csv_file_data.describe())
# Out:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB
# None
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# ...

# %% [markdown]
# Q7.
# Filter the dataset to include only:
# emp_id, emp_age, role
# Then:
# Select employees whose age is between 25 and 40
# Sort them by emp_id
# Display the last 3 rows of the result

# %%
csv_data = pd.read_csv("staff_data.csv",usecols=['emp_id', 'emp_age', 'role'])
filter_condation = ((csv_data['emp_age'] >= 25)& (csv_data['emp_age'] <= 40) )
filter_data = csv_data[filter_condation]
cort_by_emp_ids = filter_data.sort_values(by='emp_id')
last_row = cort_by_emp_ids.tail(3)
# print(csv_data)
print(cort_by_emp_ids)
print(last_row)

# %% [markdown]
# Q8.
# Filter the DataFrame to show only employees working in the "HR" role.
# Print the filtered data
# Show the total number of HR employees

# %%
csv_data = pd.read_csv("staff_data.csv")
condation = ((csv_data['role'] == 'HR Manager') | (csv_data['role'] == 'HR Executive'))
result = csv_data[condation]
total_hr_employ = len(result)
print(result)
print(total_hr_employ)
